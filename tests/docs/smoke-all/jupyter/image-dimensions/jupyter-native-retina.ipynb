# %% [raw]
# ---
# _quarto:
#   tests:
#     html:
#       ensureHtmlElements:
#         # Ensure that quarto renders the image to the same size as they
#         # the are displayed in jupyter-lab or notebook.
#         - ['img[width="450"][height="331"]']
# ---

# %%
from IPython.display import Image, display
display(Image("images/websites-quarto.png", retina=True))
