# %% [markdown]
# ---
# format: html
# _quarto:
#   tests:
#     html:
#       ensureHtmlElements:
#         - ['h1.title']
#         - []
# ---

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### This is a heading
#
# This is some content
